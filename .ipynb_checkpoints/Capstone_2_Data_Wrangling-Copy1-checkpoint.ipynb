# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from datetime import datetime

# %%
import seaborn as sns

# %%
# DATA IS FROM https://www.kaggle.com/austinreese/craigslist-carstrucks-data version 8. 
vehicles = pd.read_csv('../Raw Data/vehicles_v8.csv',parse_dates=True)

# %%
# CHECK FOR MISSING DATA:
sns.heatmap(vehicles.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
pd.set_option('display.max_columns', None)
vehicles.head()
# Out:
#    Unnamed: 0          id                                                url  \
# 0           0  7240372487  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1           1  7240309422  https://auburn.craigslist.org/cto/d/auburn-201...
# 2           2  7240224296  https://auburn.craigslist.org/cto/d/auburn-200...
# 3           3  7240103965  https://auburn.craigslist.org/cto/d/lanett-tru...
# 4           4  7239983776  https://auburn.craigslist.org/cto/d/auburn-200...
#
#    region                     region_url  price    year manufacturer  \
# 0  auburn  https://auburn.craigslist.org  35990  2010.0    chevrolet
# 1  auburn  https://auburn.craigslist.org   7500  2014.0      hyundai
# 2  auburn  https://auburn.craigslist.org   4900  2006.0          bmw
# 3  auburn  https://auburn.craigslist.org   2000  1974.0    chevrolet
# 4  auburn  https://auburn.craigslist.org  19500  2005.0         ford
#
#                   model  condition    cylinders    fuel  odometer  \
# 0  corvette grand sport       good  8 cylinders     gas   32742.0
# 1                sonata  excellent  4 cylinders     gas   93600.0
# 2               x3 3.0i       good  6 cylinders     gas   87046.0
# 3                  c-10       good  4 cylinders     gas  190000.0
# 4           f350 lariat  excellent  8 cylinders  diesel  116000.0
#
#   title_status transmission                VIN drive       size    type  \
# 0        clean        other  1G1YU3DW1A5106980   rwd        NaN   other
# 1        clean    automatic  5NPEC4AB0EH813529   fwd        NaN   sedan
# 2        clean    automatic                NaN   NaN        NaN     SUV
# 3        clean    automatic                NaN   rwd  full-size  pickup
# 4         lien    automatic                NaN   4wd  full-size  pickup
#
#   paint_color                                          image_url  \
# 0         NaN  https://images.craigslist.org/00N0N_ipkbHVZYf4...
# 1         NaN  https://images.craigslist.org/00s0s_gBHYmJ5o7y...
# 2        blue  https://images.craigslist.org/00B0B_5zgEGWPOrt...
# 3        blue  https://images.craigslist.org/00M0M_6o7KcDpArw...
# 4        blue  https://images.craigslist.org/00p0p_b95l1EgUfl...
#
#                                          description state        lat  \
# 0  Carvana is the safer way to buy a car During t...    al  32.590000
# 1  I'll move to another city and try to sell my c...    al  32.547500
# 2  Clean 2006 BMW X3 3.0I.  Beautiful and rare Bl...    al  32.616807
# 3  1974 chev. truck (LONG BED) NEW starter front ...    al  32.861600
# 4  2005 Ford F350 Lariat (Bullet Proofed). This t...    al  32.547500
#
#         long              posting_date
# 0 -85.480000  2020-12-02T08:11:30-0600
# 1 -85.468200  2020-12-02T02:11:50-0600
# 2 -85.464149  2020-12-01T19:50:41-0600
# 3 -85.216100  2020-12-01T15:54:45-0600
# 4 -85.468200  2020-12-01T12:53:56-0600

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458213 entries, 0 to 458212
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    458213 non-null  int64
#  1   id            458213 non-null  int64
#  2   url           458213 non-null  object
#  3   region        458213 non-null  object
#  4   region_url    458213 non-null  object
#  5   price         458213 non-null  int64
#  6   year          457163 non-null  float64
#  7   manufacturer  439993 non-null  object
#  8   model         453367 non-null  object
#  9   condition     265273 non-null  object
#  10  cylinders     287073 non-null  object
#  11  fuel          454976 non-null  object
#  12  odometer      402910 non-null  float64
#  13  title_status  455636 non-null  object
#  14  transmission  455771 non-null  object
#  15  VIN           270664 non-null  object
#  16  drive         324025 non-null  object
#  17  size          136865 non-null  object
#  18  type          345475 non-null  object
#  19  paint_color   317370 non-null  object
#  20  image_url     458185 non-null  object
#  21  description   458143 non-null  object
#  22  state         458213 non-null  object
#  23  lat           450765 non-null  float64
#  24  long          450765 non-null  float64
#  25  posting_date  458185 non-null  object
# dtypes: float64(4), int64(3), object(19)
# memory usage: 90.9+ MB

# %%
# ROMOVE IRRELEVANT COLUMNS AND COLUMNS MISSING TOO MUCH DATA
vehicles_trimmed = vehicles.drop(['Unnamed: 0','id','url','region_url',
                          'VIN','size','image_url','description'],
                         axis=1)
# REMOVE CARS PRE-1984 SO THE DATA BASE MATCHES THE RANGE OF THE EPA DATABASE
vehicles_trimmed = vehicles_trimmed[vehicles_trimmed['year'] >= 1984]

# %%
# DROP THE REMAINING ROWS WITH MISSING VALUES FOR SELECTED COLUMNS THAT ARE NOT MISSING A LOT OF DATA
col_keep = {'condition', 'cylinders', 'odometer','drive', 'type','paint_color'}
col_all = set(vehicles_trimmed.columns)
col_subset_remove_nan = col_all - col_keep
print(f" The following columns had rows with 'nan' values dropped: \n{col_subset_remove_nan}")

vehicles_trimmed.dropna(subset= col_subset_remove_nan, inplace=True)
# Out:
#  The following columns had rows with 'nan' values dropped:
# {'title_status', 'model', 'fuel', 'state', 'lat', 'long', 'year', 'region', 'price', 'manufacturer', 'transmission', 'posting_date'}

# %%
vehicles_trimmed = vehicles_trimmed.astype('string')
vehicles_trimmed['cylinders'] = vehicles_trimmed['cylinders'].str.extract('(\d+)', expand = False)
vehicles_trimmed['cylinders'] = vehicles_trimmed['cylinders'].astype(float)
vehicles_trimmed['price'] = vehicles_trimmed['price'].astype(float)
vehicles_trimmed['year'] = pd.to_numeric(vehicles_trimmed['year']).astype(int)
vehicles_trimmed['odometer'] = pd.to_numeric(vehicles_trimmed['odometer'])
vehicles_trimmed['lat'] = pd.to_numeric(vehicles_trimmed['lat'])
vehicles_trimmed['long'] = pd.to_numeric(vehicles_trimmed['long'])
vehicles_trimmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 416577 entries, 0 to 458211
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   region        416577 non-null  string
#  1   price         416577 non-null  float64
#  2   year          416577 non-null  int32
#  3   manufacturer  416577 non-null  string
#  4   model         416577 non-null  string
#  5   condition     246730 non-null  string
#  6   cylinders     262836 non-null  float64
#  7   fuel          416577 non-null  string
#  8   odometer      371234 non-null  float64
#  9   title_status  416577 non-null  string
#  10  transmission  416577 non-null  string
#  11  drive         298809 non-null  string
#  12  type          318342 non-null  string
#  13  paint_color   290644 non-null  string
#  14  state         416577 non-null  string
#  15  lat           416577 non-null  float64
#  16  long          416577 non-null  float64
#  17  posting_date  416577 non-null  string
# dtypes: float64(5), int32(1), string(12)
# memory usage: 58.8 MB

# %%
vehicles_trimmed['drive'].unique()
# Out:
# <StringArray>
# ['rwd', 'fwd', <NA>, '4wd']
# Length: 4, dtype: string

# %%
# CREATING A COLUMN TO MATCH THE "drive" TO WHAT IS IN THE EPA SPREADSHEET
vehicles_trimmed['drive_simple'] = vehicles_trimmed['drive']
vehicles_trimmed['drive_simple'] = vehicles_trimmed['drive_simple'].fillna('')

vehicles_trimmed['drive_simple'].loc[
    (vehicles_trimmed['drive_simple'] == 'fwd') | 
    (vehicles_trimmed['drive_simple'] == 'rwd')] = '2wd'

# %%
# CREATING A COLUMN TO MATCH THE "model" COLUMN TO WHAT IS IN THE EPA SPREADSHEET
vehicles_trimmed['model_epa'] = vehicles_trimmed['model'] + ' ' + vehicles_trimmed['drive_simple']

# %%
vehicles_trimmed['year_make_model'] = (vehicles_trimmed['year'].astype('Int32').map(str)+' '+
                                       vehicles_trimmed['manufacturer']+' '+
                                       vehicles_trimmed['model']+ " "+
                                       vehicles_trimmed['drive_simple']+ " "+
                                       vehicles_trimmed['transmission']+ " "+ 
                                       vehicles_trimmed['fuel'])

# %%
vehicles_trimmed['year_make_model']
# Out:
# 0         2010 chevrolet corvette grand sport 2wd other gas
# 1                     2014 hyundai sonata 2wd automatic gas
# 2                           2006 bmw x3 3.0i  automatic gas
# 4                2005 ford f350 lariat 4wd automatic diesel
# 5              2016 toyota tacoma double cab sr5  other gas
#                                 ...
# 458207    2017 audi a4 premium plus quattro awd  automat...
# 458208                  2014 cadillac srx 4wd automatic gas
# 458209                2018 hyundai tucson 4wd automatic gas
# 458210        2014 cadillac cts coupe awd 4wd automatic gas
# 458211           2008 jeep grand cherokee 4wd automatic gas
# Name: year_make_model, Length: 416577, dtype: string

# %%
# CONCATENATE A year_make_model COLUMN TO RELATE TO THE epa_vehicles spreadsheet
vehicles_trimmed['year_make_model'] = (vehicles_trimmed['year'].astype('Int32').map(str)+' '+
                                       vehicles_trimmed['manufacturer']+' '+
                                       vehicles_trimmed['model']+ " "+
                                       vehicles_trimmed['drive_simple']+ " "+
                                       vehicles_trimmed['transmission']+ " "+ 
                                       vehicles_trimmed['fuel'])

# CONVERT THE year_make_model COLUMN TO A STRING TYPE
vehicles_trimmed['year_make_model'] = vehicles_trimmed['year_make_model'].astype('string')
# REMOVE ANY "nan" IN THE STRING
vehicles_trimmed['year_make_model'] = vehicles_trimmed['year_make_model'].str.replace(' nan ',' ')


vehicles_trimmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 416577 entries, 0 to 458211
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   region           416577 non-null  string
#  1   price            416577 non-null  float64
#  2   year             416577 non-null  int32
#  3   manufacturer     416577 non-null  string
#  4   model            416577 non-null  string
#  5   condition        246730 non-null  string
#  6   cylinders        262836 non-null  float64
#  7   fuel             416577 non-null  string
#  8   odometer         371234 non-null  float64
#  9   title_status     416577 non-null  string
#  10  transmission     416577 non-null  string
#  11  drive            298809 non-null  string
#  12  type             318342 non-null  string
#  13  paint_color      290644 non-null  string
#  14  state            416577 non-null  string
#  15  lat              416577 non-null  float64
#  16  long             416577 non-null  float64
#  17  posting_date     416577 non-null  string
#  18  drive_simple     416577 non-null  string
#  19  model_epa        416577 non-null  string
#  20  year_make_model  416577 non-null  string
# dtypes: float64(5), int32(1), string(15)
# memory usage: 68.3 MB

# %%
vehicles_trimmed.head()
# Out:
#    region    price  year manufacturer                  model  condition  \
# 0  auburn  35990.0  2010    chevrolet   corvette grand sport       good
# 1  auburn   7500.0  2014      hyundai                 sonata  excellent
# 2  auburn   4900.0  2006          bmw                x3 3.0i       good
# 4  auburn  19500.0  2005         ford            f350 lariat  excellent
# 5  auburn  29590.0  2016       toyota  tacoma double cab sr5       good
#
#    cylinders    fuel  odometer title_status transmission drive    type  \
# 0        8.0     gas   32742.0        clean        other   rwd   other
# 1        4.0     gas   93600.0        clean    automatic   fwd   sedan
# 2        6.0     gas   87046.0        clean    automatic  <NA>     SUV
# 4        8.0  diesel  116000.0         lien    automatic   4wd  pickup
# 5        6.0     gas   33290.0        clean        other  <NA>  pickup
#
#   paint_color state        lat       long              posting_date  \
# 0        <NA>    al  32.590000 -85.480000  2020-12-02T08:11:30-0600
# 1        <NA>    al  32.547500 -85.468200  2020-12-02T02:11:50-0600
# 2        blue    al  32.616807 -85.464149  2020-12-01T19:50:41-0600
# 4        blue    al  32.547500 -85.468200  2020-12-01T12:53:56-0600
# 5         red    al  32.590000 -85.480000  2020-12-01T07:27:25-0600
#
#   drive_simple                 model_epa  \
# 0          2wd  corvette grand sport 2wd
# 1          2wd                sonata 2wd
# 2                               x3 3.0i
# 4          4wd           f350 lariat 4wd
# 5                 tacoma double cab sr5
#
#                                      year_make_model
# 0  2010 chevrolet corvette grand sport 2wd other gas
# 1              2014 hyundai sonata 2wd automatic gas
# 2                    2006 bmw x3 3.0i  automatic gas
# 4         2005 ford f350 lariat 4wd automatic diesel
# 5       2016 toyota tacoma double cab sr5  other gas

# %%
# CHECKING FOR MISSING VALUES AFTER TRIMMING DATA
# SOME COLUMNS ARE KEPT WITH MISSING DATA THAT CAN BE FILLED IN (VIA THE EPA TABLE OR REGRESSION), 
# OR MAY BE USEFUL FOR ANALYZING THE SMALLER SUBSET WHERE IT IS NOT NULL
sns.heatmap(vehicles_trimmed.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# DATA FROM https://www.fueleconomy.gov/feg/ws/index.shtml
# THIS DATA WILL BE USED TO FILL IN MISSING CYLINDERS, DRIVE, SIZE, AND TYPE VALUES
epa_vehicles = pd.read_csv('../Raw Data/EPA_Cars_1984-2022.csv')
# Out:
# C:\Users\George\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# SET ALL 0 VALUES TO NULL
epa_vehicles = epa_vehicles.replace([float(0), int(0)], np.nan)
# CHECK FOR MISSING DATA:
sns.heatmap(epa_vehicles.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# COMPARING vehicles_trimmed FUEL TYPES TO epa_vehicles FUEL TYPES
vehicles_trimmed['fuel'].unique()
# Out:
# <StringArray>
# ['gas', 'diesel', 'other', 'hybrid', 'electric']
# Length: 5, dtype: string

# %%
# COMPARING epa_vehicles_trimmed FUEL TYPES TO vehicles_trimmed PRIMARY FUEL TYPES
epa_vehicles['fuelType1'].unique()
# Out:
# array(['Regular Gasoline', 'Premium Gasoline', 'Diesel', 'Natural Gas',
#        'Electricity', 'Midgrade Gasoline'], dtype=object)

# %%
# COMPARING vehicles_trimmed FUEL TYPES TO epa_vehicles SECONDARY FUEL TYPES
epa_vehicles['fuelType2'].unique()
# Out:
# array([nan, 'Natural Gas', 'E85', 'Propane', 'Electricity'], dtype=object)

# %%
# REPLACE FUEL TYPES IN epa_vehicles TO MATCH WHAT IS IN THE vehicles_trimmed DATAFRAME

# REPLACE VARIOUS TYPES OF 'GASSOLINE' WITH 'GAS'
epa_vehicles['fuelType1'] = epa_vehicles['fuelType1'].replace(
    ['Regular Gasoline', 'Premium Gasoline','Midgrade Gasoline'], 'gas')
# REPLACE DIESEL, NATURAL GAS, AND ELECTRICITY WITH THE vehicles_trimmed EQUIVALENT
epa_vehicles['fuelType1'] = epa_vehicles['fuelType1'].replace(
    ['Diesel', 'Natural Gas','Electricity'], 
    ['diesel', 'other', 'electric'])
# IF THE SECONDARY FUEL IS ELECTRICTY, SET FUEL TYPE TO 'hybrid'
epa_vehicles.loc[epa_vehicles['fuelType2'] == 'Electricity', 'fuelType1'] = 'hybrid'
# IF THE SECONDARY FUEL IS NATURAL GAS, SET FUEL TYPE TO 'other'
epa_vehicles.loc[epa_vehicles['fuelType2'] == 'Natural Gas', 'fuelType1'] = 'other'
# IF THE SECONDARY FUEL IS PROPANE, SET FUEL TYPE TO 'other'
epa_vehicles.loc[epa_vehicles['fuelType2'] == 'Propane', 'fuelType1'] = 'other'

# RETURN UNIQUE fuelType1 VALUES FROM THE ipa_vehicles DATAFRAME FRO INSPECTION
epa_vehicles['fuelType1'].unique()
# Out:
# array(['gas', 'diesel', 'other', 'electric', 'hybrid'], dtype=object)

# %%
# SPLIT THE "trany" COLUMN AND SELECT THE FIRST ENTRY SO IT MATCHES THE vehicles_trimmed DATA FRAME
epa_vehicles['trany'] = epa_vehicles['trany'].str.split(' ').str[0]
# CHANGE "year" FROM FLOAT TO INT
epa_vehicles['year'] = epa_vehicles['year'].astype(int)
#epa_vehicles.head(5)

# %%
# SET "year" TO INT TYPE
epa_vehicles['year'] = epa_vehicles['year'].astype(int)

# CONCATENATE YEAR, MAKE, AND MODEL FOR LOOKUP WITH VEHICLES TABLE
epa_vehicles['year_make_model'] = (epa_vehicles['year'].map(str) +" "+ 
                                   epa_vehicles['make'].map(str) +" "+ 
                                   epa_vehicles['model'].map(str) +" "+ 
                                   epa_vehicles['trany'].map(str) +" "+ 
                                   epa_vehicles['fuelType1'].map(str))
# CHANGE THE year_make_model COLUMN FROM OBJECT TYPE TO A STRING TYPE
epa_vehicles['year_make_model'] = epa_vehicles['year_make_model'].astype('string')
# CHANGE TO LOWER CASE TO MATCH THE vehicles DF
epa_vehicles['year_make_model'] = epa_vehicles['year_make_model'].str.lower()

# %%
# CREATE A SET OF THE ORIGINAL COLUMN NAMES TO SEE WHICH COLUMNS WERE REMOVED
epa_vehicles_org_cols = set(epa_vehicles.columns)
# DROP COLUMNS WITH MOSTLY MISSING DATA
epa_vehicles_trimmed = epa_vehicles.dropna(axis = 1, thresh = 40000)
# DROP CREATED ON AND MODIFIED ON COLUMNS
epa_vehicles_trimmed = epa_vehicles_trimmed.drop(['createdOn','modifiedOn'], axis = 1)
# CREATE A SET OF THE CURRENT COLUMN NAMES TO SEE WHICH COLUMNS WERE REMOVED
epa_vehicles_trimmed_cols = set(epa_vehicles_trimmed.columns)
# COLUMNS REMOVED:
#epa_vehicles_org_cols - epa_vehicles_trimmed_cols
epa_vehicles_trimmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43359 entries, 0 to 43358
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        43359 non-null  float64
#  1   city08           43359 non-null  float64
#  2   co2              43088 non-null  float64
#  3   co2A             43359 non-null  float64
#  4   co2TailpipeGpm   43088 non-null  float64
#  5   comb08           43359 non-null  float64
#  6   cylinders        43085 non-null  float64
#  7   displ            43086 non-null  float64
#  8   drive            42173 non-null  object
#  9   feScore          43359 non-null  float64
#  10  fuelCost08       43359 non-null  float64
#  11  fuelType         43359 non-null  object
#  12  fuelType1        43359 non-null  object
#  13  ghgScore         43359 non-null  float64
#  14  ghgScoreA        43347 non-null  float64
#  15  highway08        43359 non-null  float64
#  16  id               43359 non-null  float64
#  17  make             43359 non-null  object
#  18  model            43359 non-null  object
#  19  mpgData          43344 non-null  object
#  20  phevBlended      43359 non-null  bool
#  21  trany            43348 non-null  object
#  22  UCity            43334 non-null  float64
#  23  UHighway         42840 non-null  float64
#  24  VClass           43359 non-null  object
#  25  year             43359 non-null  int32
#  26  youSaveSpend     42665 non-null  float64
#  27  year_make_model  43359 non-null  string
# dtypes: bool(1), float64(17), int32(1), object(8), string(1)
# memory usage: 8.8+ MB

# %%
# CHECK FOR MISSING DATA:
sns.heatmap(epa_vehicles_trimmed.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
for col in epa_vehicles_trimmed.columns:
    if epa_vehicles_trimmed[col].dtype == 'object':
        epa_vehicles_trimmed[col] = epa_vehicles_trimmed[col].astype('string').str.lower()
        

epa_vehicles_trimmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43359 entries, 0 to 43358
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        43359 non-null  float64
#  1   city08           43359 non-null  float64
#  2   co2              43088 non-null  float64
#  3   co2A             43359 non-null  float64
#  4   co2TailpipeGpm   43088 non-null  float64
#  5   comb08           43359 non-null  float64
#  6   cylinders        43085 non-null  float64
#  7   displ            43086 non-null  float64
#  8   drive            42173 non-null  string
#  9   feScore          43359 non-null  float64
#  10  fuelCost08       43359 non-null  float64
#  11  fuelType         43359 non-null  string
#  12  fuelType1        43359 non-null  string
#  13  ghgScore         43359 non-null  float64
#  14  ghgScoreA        43347 non-null  float64
#  15  highway08        43359 non-null  float64
#  16  id               43359 non-null  float64
#  17  make             43359 non-null  string
#  18  model            43359 non-null  string
#  19  mpgData          43344 non-null  string
#  20  phevBlended      43359 non-null  bool
#  21  trany            43348 non-null  string
#  22  UCity            43334 non-null  float64
#  23  UHighway         42840 non-null  float64
#  24  VClass           43359 non-null  string
#  25  year             43359 non-null  int32
#  26  youSaveSpend     42665 non-null  float64
#  27  year_make_model  43359 non-null  string
# dtypes: bool(1), float64(17), int32(1), string(9)
# memory usage: 8.8 MB

# %%
epa_vehicles_trimmed.head()
# Out:
#    barrels08  city08  co2  co2A  co2TailpipeGpm  comb08  cylinders  displ  \
# 0  15.695714    19.0 -1.0  -1.0      423.190476    21.0        4.0    2.0
# 1  29.964545     9.0 -1.0  -1.0      807.909091    11.0       12.0    4.9
# 2  12.207778    23.0 -1.0  -1.0      329.148148    27.0        4.0    2.2
# 3  29.964545    10.0 -1.0  -1.0      807.909091    11.0        8.0    5.2
# 4  17.347895    17.0 -1.0  -1.0      467.736842    19.0        4.0    2.2
#
#                         drive  feScore  fuelCost08 fuelType fuelType1  \
# 0            rear-wheel drive     -1.0      1950.0  regular       gas
# 1            rear-wheel drive     -1.0      3700.0  regular       gas
# 2           front-wheel drive     -1.0      1500.0  regular       gas
# 3            rear-wheel drive     -1.0      3700.0  regular       gas
# 4  4-wheel or all-wheel drive     -1.0      2650.0  premium       gas
#
#    ghgScore  ghgScoreA  highway08       id        make                model  \
# 0      -1.0       -1.0       25.0      1.0  alfa romeo   spider veloce 2000
# 1      -1.0       -1.0       14.0     10.0     ferrari           testarossa
# 2      -1.0       -1.0       33.0    100.0       dodge              charger
# 3      -1.0       -1.0       12.0   1000.0       dodge  b150/b250 wagon 2wd
# 4      -1.0       -1.0       23.0  10000.0      subaru     legacy awd turbo
#
#   mpgData  phevBlended      trany    UCity  UHighway           VClass  year  \
# 0       y        False     manual  23.3333   35.0000      two seaters  1985
# 1       n        False     manual  11.0000   19.0000      two seaters  1985
# 2       y        False     manual  29.0000   47.0000  subcompact cars  1985
# 3       n        False  automatic  12.2222   16.6667             vans  1985
# 4       n        False     manual  21.0000   32.0000     compact cars  1993
#
#    youSaveSpend                                year_make_model
# 0       -2250.0  1985 alfa romeo spider veloce 2000 manual gas
# 1      -11000.0             1985 ferrari testarossa manual gas
# 2           NaN                  1985 dodge charger manual gas
# 3      -11000.0   1985 dodge b150/b250 wagon 2wd automatic gas
# 4       -5750.0        1993 subaru legacy awd turbo manual gas

# %%
# REMAINING ROWS
epa_vehicles_trimmed['year_make_model'].count()
# Out:
# 43359

# %%
# CHECK FOR duplicate DATA in year_make_model:
#sns.heatmap(epa_vehicles_trimmed.isnull(),yticklabels=False,cbar=False,cmap='viridis')
epa_vehicles['year_make_model'].nunique()
# Out:
# 28911

# %%
epa_vehicles_trimmed.head()
# Out:
#    barrels08  city08  co2  co2A  co2TailpipeGpm  comb08  cylinders  displ  \
# 0  15.695714    19.0 -1.0  -1.0      423.190476    21.0        4.0    2.0
# 1  29.964545     9.0 -1.0  -1.0      807.909091    11.0       12.0    4.9
# 2  12.207778    23.0 -1.0  -1.0      329.148148    27.0        4.0    2.2
# 3  29.964545    10.0 -1.0  -1.0      807.909091    11.0        8.0    5.2
# 4  17.347895    17.0 -1.0  -1.0      467.736842    19.0        4.0    2.2
#
#                         drive  feScore  fuelCost08 fuelType fuelType1  \
# 0            rear-wheel drive     -1.0      1950.0  regular       gas
# 1            rear-wheel drive     -1.0      3700.0  regular       gas
# 2           front-wheel drive     -1.0      1500.0  regular       gas
# 3            rear-wheel drive     -1.0      3700.0  regular       gas
# 4  4-wheel or all-wheel drive     -1.0      2650.0  premium       gas
#
#    ghgScore  ghgScoreA  highway08       id        make                model  \
# 0      -1.0       -1.0       25.0      1.0  alfa romeo   spider veloce 2000
# 1      -1.0       -1.0       14.0     10.0     ferrari           testarossa
# 2      -1.0       -1.0       33.0    100.0       dodge              charger
# 3      -1.0       -1.0       12.0   1000.0       dodge  b150/b250 wagon 2wd
# 4      -1.0       -1.0       23.0  10000.0      subaru     legacy awd turbo
#
#   mpgData  phevBlended      trany    UCity  UHighway           VClass  year  \
# 0       y        False     manual  23.3333   35.0000      two seaters  1985
# 1       n        False     manual  11.0000   19.0000      two seaters  1985
# 2       y        False     manual  29.0000   47.0000  subcompact cars  1985
# 3       n        False  automatic  12.2222   16.6667             vans  1985
# 4       n        False     manual  21.0000   32.0000     compact cars  1993
#
#    youSaveSpend                                year_make_model
# 0       -2250.0  1985 alfa romeo spider veloce 2000 manual gas
# 1      -11000.0             1985 ferrari testarossa manual gas
# 2           NaN                  1985 dodge charger manual gas
# 3      -11000.0   1985 dodge b150/b250 wagon 2wd automatic gas
# 4       -5750.0        1993 subaru legacy awd turbo manual gas

# %%
# CREATE A DATAFRAME WITH ONLY UNIQUE ELEMENTS OF THE year_make_model COLUMN
epa_vehicles_trimmed_unique = epa_vehicles_trimmed.drop_duplicates(subset = ['year_make_model'])
# CHECK TO MAKE SURE THE COUNT OF THIS COLUMN IS AS EXPECTED
epa_vehicles_trimmed_unique['year_make_model'].count()
# Out:
# 28911

# %%
# ALL MAKERS FROM CRAIGSLIST
craigslist_make = vehicles_trimmed['manufacturer'].unique()
# ALL MAKERS FROM EPA
epa_make = epa_vehicles_trimmed_unique['make'].str.lower().unique()

# ITTERATE THROUGH MAKERS IN BOTH LISTS AND SHOW MISS-MATCHES ALONG WITH THEIR MOST LIKELY MATCH
for manuf in craigslist_make:
    match = False
    for make in epa_make:
        if manuf == make:
            match = True
            break
    if match == False:
        possible_matches = process.extract(manuf, epa_make, limit=2)
        print(f"craigslist {manuf}:".ljust(30)  + 
              f"{possible_matches}".ljust(50) + 
              f"n={vehicles_trimmed['manufacturer'].loc[vehicles_trimmed['manufacturer'] == manuf].count()}")
        #print(f"No Match! craigslist {manuf} has no epa equivalent")
# Out:
# craigslist rover:             [('land rover', 90), ('vector', 55)]              n=1341
# craigslist alfa-romeo:        [('alfa romeo', 100), ('geo', 60)]                n=173
# craigslist harley-davidson:   [('byd', 60), ('azure dynamics', 55)]             n=112
# craigslist aston-martin:      [('aston martin', 100), ('smart', 72)]            n=34
# craigslist datsun:            [('daihatsu', 71), ('saturn', 67)]                n=2

# %%
# DROP harley-davidson AND datsun (THERE ARE NOT MANY AND THEY DO NOT CORRELATE WITH MAKERS IN epa_vehicles)
vehicles_trimmed = vehicles_trimmed.loc[
    (vehicles_trimmed['manufacturer'] != 'harley-davidson') & 
    (vehicles_trimmed['manufacturer'] != 'datsun')]

# %%
# CONVERT ALL CLOSELY MATCHED vehicles_trimmed['manufacturer'] TO MATCH THE epa_vehicles VALUE

# ALL MAKERS FROM CRAIGSLIST
craigslist_make = vehicles_trimmed['manufacturer'].unique()
# ALL MAKERS FROM EPA
epa_make = epa_vehicles_trimmed_unique['make'].str.lower().unique()

# ITTERATE THROUGH MAKERS IN BOTH LISTS AND SHOW MISS-MATCHES ALONG WITH THEIR MOST LIKELY MATCH
for manuf in craigslist_make:
    match = False
    for make in epa_make:
        if manuf == make:
            match = True
            break
    if match == False:
        possible_matches = process.extract(manuf, epa_make, limit=1)
        for match in possible_matches:
            if match[1] > 85:
                vehicles_trimmed['manufacturer'].loc[vehicles_trimmed['manufacturer'] == manuf] = match[0]

# %%
# MATCH THE DATA FRAMES

# AFTER THINKING ABOUT IT AND DOING A BIT OF RESEARCH, RUNNING FUZZYWUZZY TO MATCH OVER 20,000 COLUMNS IS A BIT MUCH.
# A BETTER APPROACH IS TO BREAK THE DATA INTO CHUNKS BASED ON YEAR AND MAKER (SINCE THESE WILL MATCH ACROSS DATA FRAMES)
    # AND THEN MATCH AFTER THAT.

# %%
for i in epa_vehicles_trimmed_unique['model'].loc[epa_vehicles_trimmed_unique['make'] == 'ford'].unique():
    print(i)
# Out:
# taurus
# taurus sho
# thunderbird
# e150 club wagon
# ltd crown victoria
# escort wagon
# taurus wagon
# f150 pickup 2wd
# f250 pickup 2wd
# ranger pickup 2wd
# f150 pickup 4wd
# ranger pickup 4wd
# aerostar van
# aerostar van awd
# e150 econoline 2wd
# e250 econoline 2wd
# aerostar wagon
# aerostar wagon awd
# explorer 2wd
# bronco 4wd
# explorer 4wd
# aspire
# mustang
# probe
# escort
# tempo
# bronco ii 4wd
# crown victoria police
# lightning f150 2wd
# ranger pickup cab chassis
# contour
# taurus ffv
# exp
# crown victoria
# laser
# windstar fwd van
# windstar fwd wagon
# crown victoria cng
# f250
# ltd
# f250 pickup 4wd
# expedition 2wd
# expedition 4wd
# escort zx2
# f250 pickup 2wd cng
# ltd wagon
# e250 econoline 2wd cng
# ranger 2wd ffv
# ranger 4wd ffv
# focus
# focus station wagon
# lightning pickup 2wd
# postal vehicle
# windstar fwd cargo van
# f150 pickup 2wd cng
# explorer sport trac 2wd
# explorer sport trac 4wd
# escape 2wd
# explorer sport 2wd
# explorer usps 2wd
# escape 4wd
# explorer sport 4wd
# explorer usps 4wd
# f150 cng
# e250 cng
# taurus wagon ffv
# explorer usps 4wd ffv
# f150 dual-fuel 2wd (cng)
# f150 dual-fuel 4wd (cng)
# f150 5.0l 2wd gvwr>7599 lbs
# f150 5.0l 4wd gvwr>7599 lbs
# f150 2wd ffv base payload lt tire
# f150 2wd ffv base payload lt
# f150 4wd ffv base payload lt
# ecosport fwd
# ecosport awd
# expedition max 2wd
# expedition max 4wd
# f150 pickup 4wd xl/xlt
# mustang bullitt
# fusion hybrid taxi
# f150 pickup 2wd limited
# f150 pickup 4wd limited
# transit connect usps
# ranger 2wd incomplete
# fusion special service vehicle phev
# explorer rwd
# explorer ffv awd
# fusion special service phev
# explorer hev rwd
# explorer hev awd
# mustang ho coupe
# mustang ho convertible
# shelby gt500 mustang
# escape fwd hev
# escape awd hev
# transit t150 wagon 2wd ffv
# transit t150 wagon 4wd ffv
# festiva
# escape fwd phev
# transit connect van fwd
# f150 pickup 4wd hev
# bronco sport 4wd
# mustang mach-e awd
# mustang mach-e awd extended
# mustang mach-e rwd
# mustang mach-e rwd extended
# mustang mach 1
# f150 pickup 2wd hev
# ranger tremor 4wd
# mustang mach-e rwd california route 1
# ltd crown victoria/country squire wagon
# tempo fs

# %%
epa_vehicles_trimmed_unique[
    (epa_vehicles_trimmed_unique['fuelType1'].str.lower() == 'diesel') & 
    (epa_vehicles_trimmed_unique['year'] == 2021)
    ]
# Out:
#        barrels08  city08    co2  co2A  co2TailpipeGpm  comb08  cylinders  \
# 35933  15.924375    22.0  412.0  -1.0           412.0    24.0        6.0
# 35934  15.924375    22.0  412.0  -1.0           412.0    24.0        6.0
# 35990  17.372045    19.0  455.0  -1.0           455.0    22.0        4.0
# 35992  20.115000    18.0  525.0  -1.0           525.0    19.0        4.0
# 35993  17.372045    19.0  455.0  -1.0           455.0    22.0        4.0
# 36058  16.616739    20.0  435.0  -1.0           435.0    23.0        4.0
# 36059  16.616739    20.0  435.0  -1.0           435.0    23.0        4.0
# 36228  15.287400    22.0  411.0  -1.0           411.0    25.0        6.0
# 36229  16.616739    21.0  442.0  -1.0           442.0    23.0        6.0
# 36276  14.699423    22.0  390.0  -1.0           390.0    26.0        6.0
# 36282  15.924375    22.0  423.0  -1.0           423.0    24.0        6.0
# 36283  15.924375    21.0  436.0  -1.0           436.0    24.0        6.0
# 36285  15.924375    21.0  418.0  -1.0           418.0    24.0        6.0
# 36369  14.155000    23.0  383.0  -1.0           383.0    27.0        6.0
# 36373  14.699423    23.0  392.0  -1.0           392.0    26.0        6.0
# 36380  15.924375    22.0  430.0  -1.0           430.0    24.0        6.0
# 36389  15.924375    22.0  430.0  -1.0           430.0    24.0        6.0
# 36391  15.924375    22.0  430.0  -1.0           430.0    24.0        6.0
# 36813  16.616739    21.0  437.0  -1.0           437.0    23.0        6.0
# 36814  15.924375    21.0  421.0  -1.0           421.0    24.0        6.0
# 36815  16.616739    21.0  437.0  -1.0           437.0    23.0        6.0
# 36816  16.616739    21.0  437.0  -1.0           437.0    23.0        6.0
# 36817  16.616739    21.0  437.0  -1.0           437.0    23.0        6.0
# 36925  17.372045    20.0  444.0  -1.0           444.0    22.0        6.0
# 36229       4.0       -1.0       26.0  42966.0        jeep
# 36276       5.0       -1.0       32.0  43007.0         ram
# 36282       4.0       -1.0       28.0  43012.0        jeep
# 36283       4.0       -1.0       27.0  43013.0        jeep
# 36285       4.0       -1.0       29.0  43015.0         ram
# 36369       5.0       -1.0       33.0  43091.0   chevrolet
# 36373       5.0       -1.0       30.0  43095.0         gmc
# 36380       4.0       -1.0       26.0  43100.0   chevrolet
# 36389       4.0       -1.0       26.0  43109.0         gmc
# 36391       4.0       -1.0       26.0  43110.0         gmc
# 36813       4.0       -1.0       27.0  43492.0    cadillac
# 36814       4.0       -1.0       28.0  43493.0   chevrolet
# 36815       4.0       -1.0       27.0  43494.0   chevrolet
# 36816       4.0       -1.0       27.0  43495.0         gmc
# 36817       4.0       -1.0       27.0  43496.0         gmc
# 36925       4.0       -1.0       26.0  43593.0    cadillac
# 36927       4.0       -1.0       26.0  43595.0   chevrolet
# 36928       4.0       -1.0       26.0  43596.0   chevrolet
# 36931       4.0       -1.0       26.0  43599.0         gmc
# 36934       4.0       -1.0       26.0  43600.0         gmc
# 36951       4.0       -1.0       27.0  43616.0        ford
# 37068       5.0       -1.0       33.0  43722.0         ram
#
#                                   model mpgData  phevBlended      trany  \
# 35933                       range rover       n        False  automatic
# 35934                 range rover sport       n        False  automatic
# 35990                      colorado 4wd       n        False  automatic
# 35992                  colorado zr2 4wd       n        False  automatic
# 35993                        canyon 4wd       n        False  automatic
# 36058                      colorado 2wd       n        False  automatic
# 36059                        canyon 2wd       n        False  automatic
# 36228        wrangler 4dr ecodiesel 4wd       n        False  automatic
# 36229  wrangler rubic 4dr ecodiesel 4wd       y        False  automatic
# 36276                          1500 2wd       n        False  automatic
# 36282           gladiator ecodiesel 4wd       n        False  automatic
# 36283   gladiator rubicon ecodiesel 4wd       n        False  automatic
# 36285                          1500 4wd       n        False  automatic
# 36369                     silverado 2wd       n        False  automatic
# 36373                        sierra 2wd       n        False  automatic
# 36380                     silverado 4wd       n        False  automatic
# 36389                        sierra 4wd       n        False  automatic
# 36391                    sierra 4wd at4       n        False  automatic
# 36813                      escalade 2wd       n        False  automatic
# 36814                         tahoe 2wd       n        False  automatic
# 36815                      suburban 2wd       n        False  automatic
# 36816                         yukon 2wd       n        False  automatic
# 36817                      yukon xl 2wd       n        False  automatic
# 36925                      escalade 4wd       n        False  automatic
# 36927                         tahoe 4wd       y        False  automatic
# 36928                      suburban 4wd       n        False  automatic
# 36931                      yukon xl 4wd       n        False  automatic
# 36934                         yukon 4wd       n        False  automatic
# 36951                   f150 pickup 4wd       n        False  automatic
# 37068                      1500 hfe 2wd       n        False  automatic
#
#          UCity  UHighway                              VClass  year  \
# 35933  27.9000       NaN  standard sport utility vehicle 4wd  2021
# 35934  27.9000       NaN  standard sport utility vehicle 4wd  2021
# 35990  24.2000   39.7000             small pickup trucks 4wd  2021
# 35992  21.1000   31.2493             small pickup trucks 4wd  2021
# 35993  24.2000   39.7000             small pickup trucks 4wd  2021
# 36816       -2500.0                2021 gmc yukon 2wd automatic diesel
# 36817       -2500.0             2021 gmc yukon xl 2wd automatic diesel
# 36925       -3000.0        2021 cadillac escalade 4wd automatic diesel
# 36927       -3000.0          2021 chevrolet tahoe 4wd automatic diesel
# 36928       -3000.0       2021 chevrolet suburban 4wd automatic diesel
# 36931       -3000.0             2021 gmc yukon xl 4wd automatic diesel
# 36934       -3000.0                2021 gmc yukon 4wd automatic diesel
# 36951       -2500.0         2021 ford f150 pickup 4wd automatic diesel
# 37068       -1250.0             2021 ram 1500 hfe 2wd automatic diesel

# %%
years = range(2020,2021)
data_year = []
data_manuf = []
data_fuel = []
data_trany = []
data_model = []
data_match_model = []
data_match_score = []
vehicles_trimmed['epa_matched_model'] = np.nan

for year in years:
    manufacturers = vehicles_trimmed['manufacturer'].loc[vehicles_trimmed['year'] == year].unique()
    epa_manufacturers = epa_vehicles_trimmed_unique['make'].loc[epa_vehicles_trimmed_unique['year'] == year].unique()
    for manuf in manufacturers:
        fuels = vehicles_trimmed['fuel'].loc[
            (vehicles_trimmed['year'] == year) & 
            (vehicles_trimmed['manufacturer'] == manuf)].unique()
        epa_fuels = epa_vehicles_trimmed_unique['fuelType1'].loc[
            (epa_vehicles_trimmed_unique['year'] == year) & 
            (epa_vehicles_trimmed_unique['make'] == manuf)].unique()
        for fuel in fuels:
            transmissions = vehicles_trimmed['transmission'].loc[
                (vehicles_trimmed['year'] == year) & 
                (vehicles_trimmed['manufacturer'] == manuf) & 
                (vehicles_trimmed['fuel'] == fuel)].unique()
            epa_transmissions = epa_vehicles_trimmed_unique['trany'].loc[
                (epa_vehicles_trimmed_unique['year'] == year) & 
                (epa_vehicles_trimmed_unique['make'] == manuf) & 
                (epa_vehicles_trimmed_unique['fuelType1'] == fuel)].unique()
            for trany in transmissions:
                models = vehicles_trimmed['model_epa'].loc[
                    (vehicles_trimmed['year'] == year) & 
                    (vehicles_trimmed['manufacturer'] == manuf) & 
                    (vehicles_trimmed['fuel'] == fuel) &
                    (vehicles_trimmed['transmission'] == trany)].unique()
                    
                epa_models = epa_vehicles_trimmed_unique['model'].loc[
                    (epa_vehicles_trimmed_unique['year'] == year) & 
                    (epa_vehicles_trimmed_unique['make'] == manuf) & 
                    (epa_vehicles_trimmed_unique['fuelType1'] == fuel) &
                    (epa_vehicles_trimmed_unique['trany'] == trany)].unique()
                    
                for model in models:
                    matches = process.extract(model, epa_models,scorer=fuzz.token_set_ratio,limit = 1)
                    #print(f"{year} {manuf} {fuel} {trany} {model}: {matches}")
                    #data_year.append(year)
                    #data_manuf.append(manuf)
                    #data_fuel.append(fuel)
                    #data_trany.append(trany)
                    #data_model.append(model)
                    
                    if len(matches) == 0:
                        epa_match_model = np.nan
                        epa_match_score = np.nan
                        
                        data_match_model.append(np.nan)
                        data_match_score.append(np.nan)
                        
                    elif len(matches) > 0:
                        epa_match_model = matches[0][0]
                        epa_match_score = matches[0][1]
                        
                        data_match_model.append(epa_match_model)
                        data_match_score.append(epa_match_score)

                    
                    if epa_match_score != np.nan and epa_match_score > 0:
                        vehicles_trimmed.loc[
                        (vehicles_trimmed['year'] == year) & 
                        (vehicles_trimmed['manufacturer'] == manuf) & 
                        (vehicles_trimmed['fuel'] == fuel) &
                        (vehicles_trimmed['transmission'] == trany) & 
                        (vehicles_trimmed['model'] == model), 'epa_matched_model'] = epa_match_model

                    
#data = {'year': data_year, 'manuf':data_manuf,'fuel':data_fuel,'trany':data_trany,'model':data_model, 'epa_model_match': data_match_model,'match_score': data_match_score}

# %%
vehicles_trimmed[(vehicles_trimmed['year'] == 2020) & (vehicles_trimmed['model'] == 'mustang')]
# Out:
#                        region     price  year manufacturer    model  \
# 20445             little rock   65975.0  2020         ford  mustang
# 43621            palm springs   14500.0  2020         ford  mustang
# 89877   ft myers / SW florida   30000.0  2020         ford  mustang
# 111423         tampa bay area   26995.0  2020         ford  mustang
# 113653         tampa bay area   24995.0  2020         ford  mustang
# 135075                chicago     543.0  2020         ford  mustang
# 135217                chicago     351.0  2020         ford  mustang
# 145691             fort wayne   24930.0  2020         ford  mustang
# 145692             fort wayne   24298.0  2020         ford  mustang
# 147435           indianapolis   36300.0  2020         ford  mustang
# 147625           indianapolis   28984.0  2020         ford  mustang
# 166475                wichita   24800.0  2020         ford  mustang
# 174887            new orleans  109997.0  2020         ford  mustang
# 187696  western massachusetts  125000.0  2020         ford  mustang
# 188571  western massachusetts  125000.0  2020         ford  mustang
# 192107              ann arbor   34855.0  2020         ford  mustang
# 193730          detroit metro   29995.0  2020         ford  mustang
# 238341             eastern NC       0.0  2020         ford  mustang
# 239861           fayetteville       0.0  2020         ford  mustang
# 244606  raleigh / durham / CH       0.0  2020         ford  mustang
# 245108  raleigh / durham / CH       0.0  2020         ford  mustang
# 245983  raleigh / durham / CH       0.0  2020         ford  mustang
# 251910              las vegas   27450.0  2020         ford  mustang
# 256402             central NJ   26995.0  2020         ford  mustang
# 256566             central NJ   28995.0  2020         ford  mustang
# 262909           south jersey   28995.0  2020         ford  mustang
# 268482                 albany   38997.0  2020         ford  mustang
# 268535                 albany   29997.0  2020         ford  mustang
# 268794                 albany  125000.0  2020         ford  mustang
# 269794                 albany  125000.0  2020         ford  mustang
# 270239                 albany   39997.0  2020         ford  mustang
# 270352                 albany   30997.0  2020         ford  mustang
# 270511                 albany   30997.0  2020         ford  mustang
# 274879          hudson valley   38997.0  2020         ford  mustang
# 274962          hudson valley   29997.0  2020         ford  mustang
# 275105          hudson valley   38997.0  2020         ford  mustang
# 275269          hudson valley   38997.0  2020         ford  mustang
# 275409          hudson valley   29997.0  2020         ford  mustang
# 275749          hudson valley   29997.0  2020         ford  mustang
# 276279          hudson valley   30997.0  2020         ford  mustang
# 278199            long island       0.0  2020         ford  mustang
# 278203            long island       0.0  2020         ford  mustang
# 278204            long island       0.0  2020         ford  mustang
# 278210            long island       0.0  2020         ford  mustang
# 278212            long island       0.0  2020         ford  mustang
# 296653             cincinnati   27900.0  2020         ford  mustang
# 328366               portland   25990.0  2020         ford  mustang
# 346119                   york   32995.0  2020         ford  mustang
# 352447   greenville / upstate       0.0  2020         ford  mustang
# 356342           myrtle beach   32375.0  2020         ford  mustang
# 384384                houston   33303.0  2020         ford  mustang
# 384386                houston   33793.0  2020         ford  mustang
# 385226                 laredo       0.0  2020         ford  mustang
# 386390     mcallen / edinburg   26995.0  2020         ford  mustang
# 389475            san antonio   31995.0  2020         ford  mustang
# 394667              st george   27450.0  2020         ford  mustang
# 400644         fredericksburg   26495.0  2020         ford  mustang
# 400648         fredericksburg   26495.0  2020         ford  mustang
# 450759              lexington   21900.0  2020         ford  mustang
# 453022           fayetteville       0.0  2020         ford  mustang
#
#         condition  cylinders      fuel  odometer title_status transmission  \
# 20445        <NA>        NaN       gas       NaN        clean       manual
# 43621         new        NaN  electric       NaN        clean    automatic
# 89877    like new        8.0       gas       NaN      salvage       manual
# 111423       <NA>        NaN       gas    9699.0        clean    automatic
# 113653       <NA>        NaN       gas   23287.0        clean    automatic
# 135075       <NA>        8.0       gas       5.0        clean       manual
# 135217       <NA>        4.0       gas       5.0        clean    automatic
# 145691  excellent        NaN       gas   12674.0        clean    automatic
# 145692  excellent        NaN       gas   12875.0        clean    automatic
# 147435       good        8.0       gas    2141.0        clean       manual
# 147625       <NA>        NaN       gas   11835.0        clean    automatic
# 166475       good        NaN       gas   20267.0        clean    automatic
# 174887       <NA>        8.0       gas    1588.0        clean    automatic
# 187696  excellent        8.0       gas     633.0        clean    automatic
# 188571  excellent        8.0       gas     633.0        clean    automatic
# 192107       <NA>        NaN       gas   11052.0        clean    automatic
# 193730  excellent        4.0       gas      89.0        clean    automatic
# 238341       good        4.0       gas    6833.0        clean    automatic
# 239861       <NA>        4.0       gas    6879.0        clean       manual
# 244606       <NA>        4.0       gas    6879.0        clean       manual
# 245108       <NA>        4.0       gas    6879.0        clean       manual
# 245983       <NA>        4.0       gas    6879.0        clean       manual
# 251910       <NA>        4.0       gas    4524.0        clean    automatic
# 256402       <NA>        NaN       gas   15585.0        clean    automatic
# 256566   like new        4.0       gas   13464.0        clean    automatic
# 262909   like new        4.0       gas   13464.0        clean    automatic
# 268482  excellent        NaN       gas   10830.0        clean    automatic
# 268535  excellent        NaN       gas   18256.0        clean    automatic
# 268794  excellent        8.0       gas     633.0        clean    automatic
# 269794  excellent        8.0       gas     633.0        clean    automatic
# 270239  excellent        NaN       gas   10830.0        clean    automatic
# 270352  excellent        NaN       gas   18256.0        clean    automatic
# 270511  excellent        NaN       gas   18256.0        clean    automatic
# 274879  excellent        NaN       gas   10830.0        clean    automatic
# 274962  excellent        NaN       gas   18256.0        clean    automatic
# 275105  excellent        NaN       gas   10830.0        clean    automatic
# 275269  excellent        NaN       gas   10830.0        clean    automatic
# 275409  excellent        NaN       gas   18256.0        clean    automatic
# 275749  excellent        NaN       gas   18256.0        clean    automatic
# 276279  excellent        NaN       gas   18256.0        clean    automatic
# 278199  excellent        NaN       gas   13319.0        clean       manual
# 278203  excellent        NaN       gas     316.0        clean       manual
# 278204  excellent        NaN       gas     816.0        clean       manual
# 278210  excellent        NaN       gas    9008.0        clean    automatic
# 278212  excellent        NaN       gas     434.0        clean       manual
# 296653       <NA>        NaN       gas   15926.0        clean    automatic
# 328366       <NA>        4.0       gas    9485.0        clean    automatic
# 346119       <NA>        NaN       gas    3796.0        clean       manual
# 352447       good        4.0       gas    6833.0        clean    automatic
# 356342       good        4.0       gas    6833.0        clean    automatic
# 384384       <NA>        8.0       gas   23047.0        clean    automatic
# 384386       <NA>        8.0       gas   14437.0        clean    automatic
# 385226       <NA>        NaN       gas   16890.0        clean    automatic
# 386390       <NA>        NaN       gas    8420.0        clean       manual
# 389475       good        NaN       gas   25813.0        clean    automatic
# 394667       <NA>        4.0       gas    4524.0        clean    automatic
# 400644       <NA>        NaN       gas    9209.0        clean    automatic
# 400648       <NA>        NaN       gas    7402.0        clean    automatic
# 450759   like new        NaN       gas    6000.0      rebuilt    automatic
# 453022       <NA>        4.0       gas    6879.0        clean       manual
#
#        drive         type paint_color state        lat        long  \
# 20445   <NA>         <NA>        <NA>    ar  34.713706  -91.459600
# 43621    rwd        other        blue    ca  33.685600 -112.365900
# 89877    rwd         <NA>        blue    fl  26.667403  -81.926458
# 111423  <NA>  convertible       black    fl  28.050634  -82.460167
# 113653  <NA>  convertible       black    fl  28.050634  -82.460167
# 135075   rwd        coupe       black    il  42.134000  -87.934100
# 135217   rwd        coupe      silver    il  41.882900  -87.758200
# 145691   rwd        coupe        <NA>    in  40.573231  -84.184755
# 145692   rwd        coupe        <NA>    in  40.573231  -84.184755
# 147435  <NA>        coupe         red    in  39.414349  -87.416878
# 147625   rwd         <NA>       black    in  39.720422  -86.353668
# 166475  <NA>  convertible        grey    ks  37.640354  -97.351877
# 174887   rwd        coupe      orange    la  32.964447  -96.918586
# 187696   rwd        coupe        <NA>    ma  42.475900  -73.377300
# 188571   rwd        coupe        <NA>    ma  42.475900  -73.377300
# 192107   rwd         <NA>      orange    mi  42.285928  -83.797599
# 193730   rwd        coupe        blue    mi  42.466510  -82.899040
# 238341   rwd  convertible       white    nc  33.711509  -78.909582
# 239861   rwd  convertible      silver    nc  35.648726  -78.468908
# 244606   rwd  convertible      silver    nc  35.648726  -78.468908
# 245108   rwd  convertible      silver    nc  35.648726  -78.468908
# 245983   rwd  convertible      silver    nc  35.648726  -78.468908
# 251910   rwd        other      custom    nv  37.175631 -113.608240
# 256402  <NA>         <NA>        <NA>    nj  40.204300  -74.177900
# 256566   rwd  convertible       white    nj  40.639253  -74.262172
# 262909   rwd  convertible       white    nj  40.639253  -74.262172
# 268482   rwd  convertible       black    ny  42.598179  -73.708295
# 268535   rwd  convertible        blue    ny  42.598179  -73.708295
# 268794   rwd        coupe        <NA>    ny  42.475900  -73.377300
# 269794   rwd        coupe        <NA>    ny  42.475900  -73.377300
# 270239   rwd  convertible       black    ny  42.598179  -73.708295
# 270352   rwd  convertible        blue    ny  42.598179  -73.708295
# 270511   rwd  convertible        blue    ny  42.598179  -73.708295
# 1969  2020     lincoln  hybrid  automatic                     aviator 4wd
# 1970  2020        fiat     gas  automatic                  124 spider 2wd
# 1971  2020  alfa romeo     gas  automatic                   romeo giulia
# 1972  2020     ferrari     gas     manual               488 pista spider
#
#            epa_model_match  match_score
# 0     gladiator pickup 4wd        100.0
# 1             wrangler 4wd        100.0
# 2             cherokee 4wd        100.0
# 3              compass 4wd        100.0
# 4             cherokee 4wd        100.0
# ...                    ...          ...
# 1968          nautilus fwd         80.0
# 1969      aviator phev awd         78.0
# 1970            124 spider        100.0
# 1971                giulia        100.0
# 1972                   NaN          NaN
#
# [1973 rows x 7 columns]

# %%
year = 2021
fuel = 'gas'
maker = 'ford'
drive = 'automatic'

test_possible_epa_vehicles2 = (
    epa_vehicles_trimmed_unique['model'].loc[(epa_vehicles_trimmed_unique['year'] == year) & 
    (epa_vehicles_trimmed_unique['make'].str.lower() == maker) & 
    (epa_vehicles_trimmed_unique['trany'].str.lower() == drive) &
    (epa_vehicles_trimmed_unique['fuelType1'].str.lower() == fuel)]
    )
test_possible_epa_vehicles2
# Out:
# 36442                     ecosport fwd
# 36446                     ecosport awd
# 36560          transit connect van fwd
# 36561    transit connect wagon lwb fwd
# 36562             transit connect usps
# 36564          transit connect van ffv
# 36567    transit connect wagon lwb ffv
# 36581                     explorer rwd
# 36586                     explorer awd
# 36589                 explorer ffv awd
# 36590                 explorer hev awd
# 36774                  f150 pickup 2wd
# 36776              f150 pickup 2wd ffv
# 36781                  f150 pickup 4wd
# 36783              f150 pickup 4wd hev
# 36784              f150 pickup 4wd ffv
# 36800                 explorer hev rwd
# 36869                       ranger 4wd
# 36870                 bronco sport 4wd
# 36920                   expedition 2wd
# 36922               expedition max 2wd
# 36929                   expedition 4wd
# 36930               expedition max 4wd
# 36942                               gt
# 36945                   mustang mach 1
# 36949              f150 pickup 2wd hev
# 36950                       ranger 2wd
# 36952                ranger tremor 4wd
# 36953            ranger 2wd incomplete
# 36982                   escape fwd hev
# 36983                       escape fwd
# 36987                   escape awd hev
# 36989                       escape awd
# 37009                          mustang
# 37011                 mustang ho coupe
# 37014              mustang convertible
# 37015           mustang ho convertible
# 37016             shelby gt500 mustang
# 37033       transit t150 wagon 2wd ffv
# 37034       transit t150 wagon 4wd ffv
# 37057                         edge fwd
# 37060                         edge awd
# Name: model, dtype: string

# %%
test_actual_vehicles2 = (
    vehicles_trimmed['model_epa'].loc[(vehicles_trimmed['year'] == year) & 
    (vehicles_trimmed['manufacturer'] == maker) & 
    (vehicles_trimmed['transmission'].str.lower() == drive) &
    (vehicles_trimmed['fuel'] == fuel)]
    )
test_actual_vehicles2
# Out:
# 110582           explorer limited
# 112933       f150 xlt f-150 truck
# 116082         f350 super duty 4wd
# 119103         f250 super duty 4wd
# 119268         f350 super duty 4wd
# 119269         f350 super duty 4wd
# 212886                explorer 4wd
# 233580         f250 super duty 4wd
# 234055         f350 super duty 4wd
# 234058         f350 super duty 4wd
# 239982                   explorer
# 250826    explorer limited 4x4 4wd
# 268411                     fusion
# 268426        e-series cutaway 2wd
# 271514        e-series cutaway 2wd
# 273794        e-series cutaway 2wd
# 274098        e-series cutaway 2wd
# 275285         e350 super duty 2wd
# 276405         e350 super duty 2wd
# 276418        e-series cutaway 2wd
# 282990        e-series cutaway 2wd
# 285398        e-series cutaway 2wd
# 287556        e-series cutaway 2wd
# 353551         f250 super duty 4wd
# 354362         f350 super duty 4wd
# 354366         f350 super duty 4wd
# 358924         f250 super duty 4wd
# 359289         f350 super duty 4wd
# 359290         f350 super duty 4wd
# 376209                    f450 2wd
# 449330                  bronco 4wd
# 452841                  bronco 4wd
# 456051                  bronco 4wd
# Name: model_epa, dtype: string

# %%
for model in test_actual_vehicles2:
    matches = process.extract(model, test_possible_epa_vehicles2,scorer=fuzz.token_set_ratio,limit = 1)
    print(f"{model}: {matches}")
# Out:
# explorer limited : [('explorer rwd', 80, 36581)]
# f150 xlt f-150 truck : [('f150 pickup 2wd ffv', 51, 36776)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f250 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# explorer 4wd: [('explorer rwd', 92, 36581)]
# f250 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# explorer : [('explorer rwd', 100, 36581)]
# explorer limited 4x4 4wd: [('explorer rwd', 80, 36581)]
# fusion : [('mustang', 46, 37009)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e350 super duty 2wd: [('f150 pickup 2wd', 53, 36774)]
# e350 super duty 2wd: [('f150 pickup 2wd', 53, 36774)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# e-series cutaway 2wd: [('ranger 2wd incomplete', 49, 36953)]
# f250 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f250 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f350 super duty 4wd: [('f150 pickup 4wd', 59, 36781)]
# f450 2wd: [('f150 pickup 2wd', 61, 36774)]
# bronco 4wd: [('bronco sport 4wd', 100, 36870)]
# bronco 4wd: [('bronco sport 4wd', 100, 36870)]
# bronco 4wd: [('bronco sport 4wd', 100, 36870)]
